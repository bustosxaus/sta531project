# %%
# %%time
baseball = pd.read_csv('Pitchfx.csv',parse_dates=['game_date'])
# Out:
# CPU times: user 3min 12s, sys: 1.21 s, total: 3min 13s
# Wall time: 3min 13s

# %%
baseball.shape
# Out:
# (2114497, 39)

# %%
baseball
# Out:
#          Unnamed: 0                     game_id  game_date  year  \
# 0                 1  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 1                 2  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 2                 3  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 3                 4  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 4                 5  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 5                 6  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 6                 7  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 7                 8  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 8                 9  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 9                10  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 10               11  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 11               12  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 12               13  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 13               14  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 14               15  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 15               16  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 16               17  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 17               18  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 18               19  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 19               20  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 20               21  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 21               22  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 22               23  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 23               24  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 24               25  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 25               26  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 26               27  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 27               28  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 28               29  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# 29               30  2013/04/01/anamlb-cinmlb-1 2013-04-01  2013
# ...             ...                         ...        ...   ...
# 2114467     2114468  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114468     2114469  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114469     2114470  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114470     2114471  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114471     2114472  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114472     2114473  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114473     2114474  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114474     2114475  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114475     2114476  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114476     2114477  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114477     2114478  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114478     2114479  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114479     2114480  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114480     2114481  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114481     2114482  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114482     2114483  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114483     2114484  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114484     2114485  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114485     2114486  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114486     2114487  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114487     2114488  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114488     2114489  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114489     2114490  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114490     2114491  2015/10/04/tormlb-tbamlb-1 2015-10-04  2015
# 2114491     2114492  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114492     2114493  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114493     2114494  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114494     2114495  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114495     2114496  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
# 2114496     2114497  2015/10/04/wasmlb-nynmlb-1 2015-10-04  2015
#
#            sv_pitch_id  at_bat_number  pitch_number  inning top_inning_sw  \
# 0        130401_170118             23             1       3             N
# 1        130401_170156             23             2       3             N
# 2        130401_170223             23             3       3             N
# 3        130401_170243             23             4       3             N
# 4        130401_170306             23             5       3             N
# 5        130401_170353             23             6       3             N
# 6        130401_170442             23             7       3             N
# 7        130401_175556             43             1       6             N
# 8        130401_175610             43             2       6             N
# 9        130401_175653             43             3       6             N
# 10       130401_194905             80             1      11             Y
# 11       130401_194935             80             2      11             Y
# 12       130401_174447             38             1       6             Y
# 13       130401_174458             38             2       6             Y
# 14       130401_174512             38             3       6             Y
# 15       130401_174531             38             4       6             Y
# 16       130401_174754             40             1       6             Y
# 17       130401_174839             40             2       6             Y
# 18       130401_174907             40             3       6             Y
# 19       130401_182043             52             1       7             N
# 20       130401_182100             52             2       7             N
# 21       130401_182118             52             3       7             N
# 22       130401_182137             52             4       7             N
# 23       130401_182208             52             5       7             N
# 24       130401_195012             80             3      11             Y
# 25       130401_195041             80             4      11             Y
# 26       130401_195643             82             1      11             N
# 27       130401_195703             82             2      11             N
# 28       130401_195742             82             3      11             N
# 29       130401_195810             82             4      11             N
# ...                ...            ...           ...     ...           ...
# 2114467  151004_172819             56             4       8             N
# 2114468  151004_172850             56             5       8             N
# 2114469  151004_173441             58             1       9             Y
# 2114470  151004_173501             58             2       9             Y
# 2114471  151004_173524             58             3       9             Y
# 2114472  151004_173545             58             4       9             Y
# 2114473  151004_173614             58             5       9             Y
# 2114474  151004_153649             12             2       2             Y
# 2114475  151004_153714             12             3       2             Y
# 2114476  151004_153745             12             4       2             Y
# 2114477  151004_153809             12             5       2             Y
# 2114478  151004_165858             45             5       7             Y
# 2114479  151004_172450             54             1       8             N
# 2114480  151004_172508             54             2       8             N
# 2114481  151004_172525             54             3       8             N
# 2114482  151004_160856             24             5       4             Y
# 2114483  151004_164243             38             1       6             Y
# 2114484  151004_164257             38             2       6             Y
# 2114485  151004_164319             38             3       6             Y
# 2114486  151004_171614             51             1       8             Y
# 2114487  151004_171634             51             2       8             Y
# 2114488  151004_171718             51             3       8             Y
# 2114489  151004_171739             51             4       8             Y
# 2114490  151004_180825             71             4       8             N
# 2114491  151004_161428             27             1       4             N
# 2114492  151004_161441             27             2       4             N
# 2114493  151004_161456             27             3       4             N
# 2114494  151004_161512             27             4       4             N
# 2114495  151004_161532             27             5       4             N
# 2114496  151004_161554             27             6       4             N
#
#                    event_type       ...       init_vel_y  init_vel_z  \
# 0                        foul       ...         -126.870      -5.638
# 1                        foul       ...         -124.581      -5.768
# 2                        ball       ...         -125.363       0.349
# 3                        ball       ...         -114.953      -0.691
# 4                        foul       ...         -116.203      -4.610
# 5                blocked_ball       ...         -118.220      -7.585
# 6                        ball       ...         -129.421      -9.949
# 7                        ball       ...         -122.380      -3.353
# 8                        foul       ...         -120.357      -5.241
# 9               hit_into_play       ...         -113.884      -3.757
# 10                       ball       ...         -118.727      -4.248
# 11                       ball       ...         -129.441      -6.941
# 12              called_strike       ...         -130.027      -4.413
# 13            swinging_strike       ...         -121.831      -2.881
# 14                       foul       ...         -127.907      -3.287
# 15              called_strike       ...         -122.582      -3.907
# 16              called_strike       ...         -128.820      -4.526
# 17              called_strike       ...         -128.069      -4.033
# 18              hit_into_play       ...         -134.269      -2.152
# 19              called_strike       ...         -138.525      -7.797
# 20                       ball       ...         -126.295      -2.577
# 21            swinging_strike       ...         -138.356      -7.761
# 22                       foul       ...         -125.040      -3.334
# 23              hit_into_play       ...         -137.197      -3.300
# 24                       ball       ...         -113.833       1.136
# 25                       ball       ...         -130.765      -2.701
# 26              called_strike       ...         -136.824      -8.908
# 27                       ball       ...         -123.322      -8.277
# 28                       foul       ...         -125.428      -4.904
# 29       hit_into_play_no_out       ...         -139.117      -9.627
# ...                       ...       ...              ...         ...
# 2114467                  ball       ...         -128.921      -8.884
# 2114468                  ball       ...         -142.989      -9.737
# 2114469                  ball       ...         -140.610      -4.602
# 2114470         called_strike       ...         -140.173      -5.659
# 2114471                  ball       ...         -127.288      -6.839
# 2114472                  ball       ...         -139.923      -3.809
# 2114473         hit_into_play       ...         -141.852      -6.477
# 2114474       swinging_strike       ...         -137.815      -4.221
# 2114475                  foul       ...         -136.996      -5.009
# 2114476                  ball       ...         -123.231      -2.508
# 2114477         hit_into_play       ...         -120.459      -1.780
# 2114478  hit_into_play_no_out       ...         -131.078      -2.562
# 2114479         called_strike       ...         -141.925      -5.529
# 2114480                  ball       ...         -131.968      -5.936
# 2114481         hit_into_play       ...         -143.297      -5.061
# 2114482       swinging_strike       ...         -123.342      -0.389
# 2114483       swinging_strike       ...         -131.066      -4.692
# 2114484                  foul       ...         -131.035      -6.664
# 2114485         called_strike       ...         -132.719      -8.040
# 2114486       swinging_strike       ...         -132.606      -4.005
# 2114487             foul_bunt       ...         -113.703      -6.292
# 2114488                  foul       ...         -132.957      -3.418
# 2114489         hit_into_play       ...         -119.523       0.889
# 2114490         hit_into_play       ...         -119.453      -2.851
# 2114491         called_strike       ...         -123.923      -1.224
# 2114492                  ball       ...         -120.285      -3.376
# 2114493         called_strike       ...         -136.117      -3.824
# 2114494                  ball       ...         -134.589      -0.532
# 2114495                  ball       ...         -135.328      -1.098
# 2114496  hit_into_play_no_out       ...         -124.127      -0.465
#
#          init_accel_x  init_accel_y  init_accel_z  HitTrajectory  \
# 0               2.494        26.247       -10.444              U
# 1              -7.240        24.589       -14.975              U
# 2              -0.823        24.928       -15.351              U
# 3              -9.387        22.898       -19.355              U
# 4              -7.410        22.774       -16.539              U
# 5               2.771        19.941       -28.319              U
# 6               4.487        26.542        -9.052              U
# 7               2.938        23.932       -14.308  bunt_grounder
# 8               3.347        19.875       -13.703  bunt_grounder
# 9               8.031        17.989       -31.293  bunt_grounder
# 10              3.840        19.410       -28.799              U
# 11            -16.290        27.226       -20.642              U
# 12            -15.304        31.361       -14.274              U
# 13              2.952        22.086       -29.000              U
# 14              0.035        24.347       -20.640              U
# 15              3.065        18.409       -28.305              U
# 16             -2.848        22.649       -19.702       fly_ball
# 17              2.104        21.970       -22.352       fly_ball
# 18             -4.708        26.184       -11.028       fly_ball
# 19              1.568        28.850       -14.085     line_drive
# 20              2.920        23.916       -35.431     line_drive
# 21              3.864        30.706       -13.685     line_drive
# 22              8.420        23.192       -40.966     line_drive
# 23            -10.988        30.091       -20.192     line_drive
# 24              5.999        17.837       -28.891              U
# 25             -9.487        27.369       -11.318              U
# 26             -6.978        28.526        -8.981    ground_ball
# 27              3.732        22.265       -27.137    ground_ball
# 28              2.047        25.543       -28.939    ground_ball
# 29            -17.070        30.189       -11.027    ground_ball
# ...               ...           ...           ...            ...
# 2114467         2.957        27.245       -38.149              U
# 2114468       -22.671        35.050       -27.025              U
# 2114469       -16.351        36.188       -23.221    ground_ball
# 2114470       -17.960        37.195       -22.095    ground_ball
# 2114471         4.508        26.301       -36.402    ground_ball
# 2114472       -16.357        33.387       -25.766    ground_ball
# 2114473       -18.314        34.048       -21.732    ground_ball
# 2114474        -7.880        34.498       -12.570     line_drive
# 2114475        -9.079        34.579       -16.298     line_drive
# 2114476         8.002        27.458       -37.843     line_drive
# 2114477         7.255        27.705       -36.128     line_drive
# 2114478         4.599        32.750       -22.679    ground_ball
# 2114479       -15.581        32.526       -22.667    ground_ball
# 2114480         0.419        24.668       -38.634    ground_ball
# 2114481       -20.659        33.151       -24.535    ground_ball
# 2114482        -9.042        35.368       -26.840              U
# 2114483       -10.470        31.043       -17.198              U
# 2114484       -10.412        32.141       -13.681              U
# 2114485       -13.920        33.025       -14.485              U
# 2114486        -1.361        33.936       -11.265       fly_ball
# 2114487       -11.812        25.897       -17.772       fly_ball
# 2114488        -6.072        30.952       -12.655       fly_ball
# 2114489         1.688        33.739       -36.460       fly_ball
# 2114490        16.647        23.817       -24.337     line_drive
# 2114491        -0.717        27.887       -33.629     line_drive
# 2114492         1.387        24.523       -35.545     line_drive
# 2114493       -19.050        33.669       -19.643     line_drive
# 2114494        -7.797        33.548       -16.499     line_drive
# 2114495       -20.099        33.405       -22.108     line_drive
# 2114496         4.150        27.770       -35.053     line_drive
#
#                                                 PlaybyPlay Runneron1st_ID  \
# 0                                      Ryan Ludwick walks.            NaN
# 1                                      Ryan Ludwick walks.            NaN
# 2                                      Ryan Ludwick walks.            NaN
# 3                                      Ryan Ludwick walks.            NaN
# 4                                      Ryan Ludwick walks.            NaN
# 5                                      Ryan Ludwick walks.            NaN
# 6                                      Ryan Ludwick walks.            NaN
# 7        Chris Heisey bunt grounds out, catcher Chris I...            NaN
# 8        Chris Heisey bunt grounds out, catcher Chris I...            NaN
# 9        Chris Heisey bunt grounds out, catcher Chris I...            NaN
# 10                                  Howard Kendrick walks.            NaN
# 11                                  Howard Kendrick walks.            NaN
# 12                     Jered Weaver called out on strikes.            NaN
# 13                     Jered Weaver called out on strikes.            NaN
# 14                     Jered Weaver called out on strikes.            NaN
# 15                     Jered Weaver called out on strikes.            NaN
# 16       Erick Aybar flies out softly to left fielder C...       545361.0
# 17       Erick Aybar flies out softly to left fielder C...       545361.0
# 18       Erick Aybar flies out softly to left fielder C...       545361.0
# 19       Zack Cozart lines out to center fielder Mike T...            NaN
# 20       Zack Cozart lines out to center fielder Mike T...            NaN
# 21       Zack Cozart lines out to center fielder Mike T...            NaN
# 22       Zack Cozart lines out to center fielder Mike T...            NaN
# 23       Zack Cozart lines out to center fielder Mike T...            NaN
# 24                                  Howard Kendrick walks.            NaN
# 25                                  Howard Kendrick walks.            NaN
# 26       Joey Votto reaches on a fielding error by shor...            NaN
# 27       Joey Votto reaches on a fielding error by shor...            NaN
# 28       Joey Votto reaches on a fielding error by shor...            NaN
# 29       Joey Votto reaches on a fielding error by shor...            NaN
# ...                                                    ...            ...
# 2114467                                David Wright walks.            NaN
# 2114468                                David Wright walks.            NaN
# 2114469  Anthony Rendon grounds out sharply, second bas...            NaN
# 2114470  Anthony Rendon grounds out sharply, second bas...            NaN
# 2114471  Anthony Rendon grounds out sharply, second bas...            NaN
# 2114472  Anthony Rendon grounds out sharply, second bas...            NaN
# 2114473  Anthony Rendon grounds out sharply, second bas...            NaN
# 2114474  Pedro Severino lines out to third baseman Davi...       572191.0
# 2114475  Pedro Severino lines out to third baseman Davi...       572191.0
# 2114476  Pedro Severino lines out to third baseman Davi...       572191.0
# 2114477  Pedro Severino lines out to third baseman Davi...       572191.0
# 2114478  Clint Robinson singles on a sharp ground ball ...            NaN
# 2114479  Juan Lagares grounds out, pitcher Blake Treine...            NaN
# 2114480  Juan Lagares grounds out, pitcher Blake Treine...            NaN
# 2114481  Juan Lagares grounds out, pitcher Blake Treine...            NaN
# 2114482                 Jayson Werth strikes out swinging.            NaN
# 2114483              Anthony Rendon called out on strikes.            NaN
# 2114484              Anthony Rendon called out on strikes.            NaN
# 2114485              Anthony Rendon called out on strikes.            NaN
# 2114486  Michael Taylor flies out to center fielder Jua...            NaN
# 2114487  Michael Taylor flies out to center fielder Jua...            NaN
# 2114488  Michael Taylor flies out to center fielder Jua...            NaN
# 2114489  Michael Taylor flies out to center fielder Jua...            NaN
# 2114490  Mikie Mahtook lines out sharply to right field...            NaN
# 2114491  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
# 2114492  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
# 2114493  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
# 2114494  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
# 2114495  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
# 2114496  Yoenis Cespedes doubles (42) on a sharp line d...            NaN
#
#          Runneron2nd_ID  Runneron3rd_ID
# 0                   NaN        425783.0
# 1                   NaN        425783.0
# 2                   NaN        425783.0
# 3                   NaN        425783.0
# 4                   NaN        425783.0
# 5                   NaN        425783.0
# 6                   NaN        425783.0
# 7                   NaN             NaN
# 8                   NaN             NaN
# 9                   NaN             NaN
# 10             461865.0             NaN
# 11             461865.0             NaN
# 12                  NaN             NaN
# 13                  NaN             NaN
# 14                  NaN             NaN
# 15                  NaN             NaN
# 16                  NaN             NaN
# 17                  NaN             NaN
# 18                  NaN             NaN
# 19                  NaN             NaN
# 20                  NaN             NaN
# 21                  NaN             NaN
# 22                  NaN             NaN
# 23                  NaN             NaN
# 24             461865.0             NaN
# 25             461865.0             NaN
# 26                  NaN             NaN
# 27                  NaN             NaN
# 28                  NaN             NaN
# 29                  NaN             NaN
# ...                 ...             ...
# 2114467             NaN             NaN
# 2114468             NaN             NaN
# 2114469             NaN             NaN
# 2114470             NaN             NaN
# 2114471             NaN             NaN
# 2114472             NaN             NaN
# 2114473             NaN             NaN
# 2114474        435622.0             NaN
# 2114475        435622.0             NaN
# 2114476        435622.0             NaN
# 2114477        435622.0             NaN
# 2114478             NaN             NaN
# 2114479             NaN             NaN
# 2114480             NaN             NaN
# 2114481             NaN             NaN
# 2114482             NaN             NaN
# 2114483             NaN             NaN
# 2114484             NaN             NaN
# 2114485             NaN             NaN
# 2114486             NaN             NaN
# 2114487             NaN             NaN
# 2114488             NaN             NaN
# 2114489             NaN             NaN
# 2114490             NaN             NaN
# 2114491             NaN             NaN
# 2114492             NaN             NaN
# 2114493             NaN             NaN
# 2114494             NaN             NaN
# 2114495             NaN             NaN
# 2114496             NaN             NaN
#
# [2114497 rows x 39 columns]

# %%
baseball.dtypes
# Out:
# Unnamed: 0                 int64
# game_id                   object
# game_date         datetime64[ns]
# year                       int64
# sv_pitch_id               object
# at_bat_number              int64
# pitch_number               int64
# inning                     int64
# top_inning_sw             object
# event_type                object
# event_result              object
# pre_balls                  int64
# pre_strikes                int64
# pre_outs                   int64
# batter_id                  int64
# bat_side                  object
# pitcher_id                 int64
# throws                    object
# initial_speed            float64
# plate_speed              float64
# pitch_type                object
# break_x                  float64
# break_z                  float64
# plate_x                  float64
# plate_z                  float64
# init_pos_x               float64
# init_pos_y                 int64
# init_pos_z               float64
# init_vel_x               float64
# init_vel_y               float64
# init_vel_z               float64
# init_accel_x             float64
# init_accel_y             float64
# init_accel_z             float64
# HitTrajectory             object
# PlaybyPlay                object
# Runneron1st_ID           float64
# Runneron2nd_ID           float64
# Runneron3rd_ID           float64
# dtype: object

# %%
baseball.event_result.unique()
# Out:
# array([nan, 'walk', 'field_out', 'strikeout', 'field_error', 'intent_walk',
#        'single', 'stolen_base_2b', 'wild_pitch', 'home_run',
#        'hit_by_pitch', 'sac_bunt', 'force_out', 'double',
#        'grounded_into_double_play', 'sac_fly', 'triple',
#        'caught_stealing_2b', 'double_play', 'fielders_choice_out',
#        'passed_ball', 'caught_stealing_3b', 'fielders_choice', 'other_out',
#        'stolen_base_3b', 'balk', 'catcher_interf', 'strikeout_double_play',
#        'triple_play', 'sac_fly_double_play', 'caught_stealing_home',
#        'other_advance', 'sac_bunt_double_play', 'stolen_base_home',
#        'pickoff_caught_stealing_2b', 'pickoff_caught_stealing_home',
#        'runner_double_play'], dtype=object)

# %%
baseball.describe()
# Out:
#          Unnamed: 0          year  at_bat_number  pitch_number        inning  \
# count  2.114497e+06  2.114497e+06   2.114497e+06  2.114497e+06  2.114497e+06
# mean   1.057249e+06  2.013997e+03   3.904800e+01  2.871028e+00  5.034110e+00
# std    6.104029e+05  8.170926e-01   2.322825e+01  1.715838e+00  2.705246e+00
# min    1.000000e+00  2.013000e+03   1.000000e+00  1.000000e+00  1.000000e+00
# 25%    5.286250e+05  2.013000e+03   1.900000e+01  1.000000e+00  3.000000e+00
# 50%    1.057249e+06  2.014000e+03   3.800000e+01  3.000000e+00  5.000000e+00
# 75%    1.585873e+06  2.015000e+03   5.800000e+01  4.000000e+00  7.000000e+00
# max    2.114497e+06  2.015000e+03   1.680000e+02  1.600000e+01  2.000000e+01
#
#           pre_balls   pre_strikes      pre_outs     batter_id    pitcher_id  \
# count  2.114497e+06  2.114497e+06  2.114497e+06  2.114497e+06  2.114497e+06
# mean   8.699908e-01  8.726974e-01  9.865193e-01  4.709175e+05  4.796297e+05
# std    9.600661e-01  8.237662e-01  8.184424e-01  9.083001e+04  8.375787e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.100290e+05  1.125260e+05
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  4.352630e+05  4.468990e+05
# 50%    1.000000e+00  1.000000e+00  1.000000e+00  4.618150e+05  4.765890e+05
# 75%    1.000000e+00  2.000000e+00  2.000000e+00  5.192990e+05  5.349100e+05
# max    4.000000e+00  2.000000e+00  2.000000e+00  6.569410e+05  6.487370e+05
#
#             ...          init_pos_z    init_vel_x    init_vel_y    init_vel_z  \
# count       ...        2.114497e+06  2.114497e+06  2.114497e+06  2.114497e+06
# mean        ...        5.883682e+00  1.932356e+00 -1.285879e+02 -4.475266e+00
# std         ...        4.496474e-01  5.910096e+00  8.736547e+00  3.089400e+00
# min         ...        1.841000e+00 -2.472800e+01 -1.518800e+02 -2.095000e+01
# 25%         ...        5.638000e+00 -2.638000e+00 -1.351870e+02 -6.580000e+00
# 50%         ...        5.904000e+00  3.560000e+00 -1.306170e+02 -4.660000e+00
# 75%         ...        6.162000e+00  6.258000e+00 -1.228380e+02 -2.568000e+00
# max         ...        9.614000e+00  2.154200e+01 -5.868400e+01  1.347800e+01
#
#        init_accel_x  init_accel_y  init_accel_z  Runneron1st_ID  \
# count  2.114497e+06  2.114497e+06  2.114497e+06   598969.000000
# mean  -1.627922e+00  2.692647e+01 -2.296861e+01   469348.519448
# std    1.075237e+01  4.398023e+00  8.863438e+00    91443.421088
# min   -3.827300e+01  8.820000e-01 -5.683200e+01   110029.000000
# 25%   -1.067000e+01  2.375300e+01 -2.876800e+01   435063.000000
# 50%   -2.589000e+00  2.690100e+01 -2.177600e+01   461235.000000
# 75%    6.755000e+00  3.001600e+01 -1.602700e+01   519184.000000
# max    4.018100e+01  5.802600e+01  2.378000e+01   656941.000000
#
#        Runneron2nd_ID  Runneron3rd_ID
# count   411493.000000   212153.000000
# mean    473040.356652   474168.616550
# std      88123.455300    88539.299873
# min     110029.000000   110029.000000
# 25%     435559.000000   435622.000000
# 50%     461882.000000   462101.000000
# 75%     519299.000000   523253.000000
# max     656941.000000   656941.000000
#
# [8 rows x 28 columns]

# %%
baseball.pitch_type.describe()
# Out:
# count     2114259
# unique         18
# top            FF
# freq       742398
# Name: pitch_type, dtype: object

# %%
baseball.isnull().sum()
# Out:
# Unnamed: 0              0
# game_id                 0
# game_date               0
# year                    0
# sv_pitch_id             0
# at_bat_number           0
# pitch_number            0
# inning                  0
# top_inning_sw           0
# event_type              0
# event_result      1547557
# pre_balls               0
# pre_strikes             0
# pre_outs                0
# batter_id               0
# bat_side                0
# pitcher_id              0
# throws                  0
# initial_speed           0
# plate_speed             0
# pitch_type            238
# break_x                 0
# break_z                 0
# plate_x                 0
# plate_z                 0
# init_pos_x              0
# init_pos_y              0
# init_pos_z              0
# init_vel_x              0
# init_vel_y              0
# init_vel_z              0
# init_accel_x            0
# init_accel_y            0
# init_accel_z            0
# HitTrajectory          78
# PlaybyPlay              0
# Runneron1st_ID    1515528
# Runneron2nd_ID    1703004
# Runneron3rd_ID    1902344
# dtype: int64

# %%
baseball.HitTrajectory.unique()
# Out:
# array(['U', 'bunt_grounder', 'fly_ball', 'line_drive', 'ground_ball',
#        'popup', 'bunt_popup', nan, 'bunt_line_drive'], dtype=object)

# %%
baseball.event_result.describe()
# Out:
# count        566940
# unique           36
# top       field_out
# freq         229505
# Name: event_result, dtype: object

# %%
len(baseball.pitcher_id.unique())
# Out:
# 1045

# %%
baseball.PlaybyPlay.describe()
# Out:
# count                                2114497
# unique                                359695
# top       Chris Carter strikes out swinging.
# freq                                    1892
# Name: PlaybyPlay, dtype: object

# %%
baseball_sel = baseball[['game_id','game_date','sv_pitch_id','pitch_number','inning','top_inning_sw','event_type','pre_balls','pre_strikes','pre_outs','batter_id','bat_side','pitcher_id','throws','pitch_type','Runneron1st_ID','Runneron2nd_ID','Runneron3rd_ID']]

# %%
baseball_sel = baseball_sel[baseball_sel.pitch_type.notnull()]

# %%
baseball_sel.shape
# Out:
# (2114259, 18)

# %%
baseball_sel.dtypes
# Out:
# game_id                   object
# game_date         datetime64[ns]
# sv_pitch_id               object
# pitch_number               int64
# inning                     int64
# top_inning_sw             object
# event_type                object
# pre_balls                  int64
# pre_strikes                int64
# pre_outs                   int64
# batter_id                  int64
# bat_side                  object
# pitcher_id                 int64
# throws                    object
# pitch_type                object
# Runneron1st_ID           float64
# Runneron2nd_ID           float64
# Runneron3rd_ID           float64
# dtype: object

# %%
baseball_sel.isnull().sum()
# Out:
# game_id                 0
# game_date               0
# sv_pitch_id             0
# pitch_number            0
# inning                  0
# top_inning_sw           0
# event_type              0
# pre_balls               0
# pre_strikes             0
# pre_outs                0
# batter_id               0
# bat_side                0
# pitcher_id              0
# throws                  0
# pitch_type              0
# Runneron1st_ID    1515352
# Runneron2nd_ID    1702807
# Runneron3rd_ID    1902128
# dtype: int64

# %%
baseball_sel
# Out:
#                             game_id  game_date    sv_pitch_id  pitch_number  \
# 0        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170118             1
# 1        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170156             2
# 2        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170223             3
# 3        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170243             4
# 4        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170306             5
# 5        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170353             6
# 6        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_170442             7
# 7        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_175556             1
# 8        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_175610             2
# 9        2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_175653             3
# 10       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_194905             1
# 11       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_194935             2
# 12       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174447             1
# 13       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174458             2
# 14       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174512             3
# 15       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174531             4
# 16       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174754             1
# 17       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174839             2
# 18       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_174907             3
# 19       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_182043             1
# 20       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_182100             2
# 21       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_182118             3
# 22       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_182137             4
# 23       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_182208             5
# 24       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195012             3
# 25       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195041             4
# 26       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195643             1
# 27       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195703             2
# 28       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195742             3
# 29       2013/04/01/anamlb-cinmlb-1 2013-04-01  130401_195810             4
# ...                             ...        ...            ...           ...
# 2114467  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_172819             4
# 2114468  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_172850             5
# 2114469  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_173441             1
# 2114470  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_173501             2
# 2114471  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_173524             3
# 2114472  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_173545             4
# 2114473  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_173614             5
# 2114474  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_153649             2
# 2114475  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_153714             3
# 2114476  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_153745             4
# 2114477  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_153809             5
# 2114478  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_165858             5
# 2114479  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_172450             1
# 2114480  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_172508             2
# 2114481  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_172525             3
# 2114482  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_160856             5
# 2114483  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_164243             1
# 2114484  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_164257             2
# 2114485  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_164319             3
# 2114486  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_171614             1
# 2114487  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_171634             2
# 2114488  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_171718             3
# 2114489  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_171739             4
# 2114490  2015/10/04/tormlb-tbamlb-1 2015-10-04  151004_180825             4
# 2114491  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161428             1
# 2114492  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161441             2
# 2114493  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161456             3
# 2114494  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161512             4
# 2114495  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161532             5
# 2114496  2015/10/04/wasmlb-nynmlb-1 2015-10-04  151004_161554             6
#
#          inning top_inning_sw            event_type  pre_balls  pre_strikes  \
# 0             3             N                  foul          0            0
# 1             3             N                  foul          0            1
# 2             3             N                  ball          0            2
# 3             3             N                  ball          1            2
# 4             3             N                  foul          2            2
# 5             3             N          blocked_ball          2            2
# 6             3             N                  ball          3            2
# 7             6             N                  ball          0            0
# 8             6             N                  foul          1            0
# 9             6             N         hit_into_play          1            1
# 10           11             Y                  ball          0            0
# 11           11             Y                  ball          1            0
# 12            6             Y         called_strike          0            0
# 13            6             Y       swinging_strike          0            1
# 14            6             Y                  foul          0            2
# 15            6             Y         called_strike          0            2
# 16            6             Y         called_strike          0            0
# 17            6             Y         called_strike          0            1
# 18            6             Y         hit_into_play          0            2
# 19            7             N         called_strike          0            0
# 20            7             N                  ball          0            1
# 21            7             N       swinging_strike          1            1
# 22            7             N                  foul          1            2
# 23            7             N         hit_into_play          1            2
# 24           11             Y                  ball          2            0
# 25           11             Y                  ball          3            0
# 26           11             N         called_strike          0            0
# 27           11             N                  ball          0            1
# 28           11             N                  foul          1            1
# 29           11             N  hit_into_play_no_out          1            2
# ...         ...           ...                   ...        ...          ...
# 2114467       8             N                  ball          2            1
# 2114468       8             N                  ball          3            1
# 2114469       9             Y                  ball          0            0
# 2114470       9             Y         called_strike          1            0
# 2114471       9             Y                  ball          1            1
# 2114472       9             Y                  ball          2            1
# 2114473       9             Y         hit_into_play          3            1
# 2114474       2             Y       swinging_strike          1            0
# 2114475       2             Y                  foul          1            1
# 2114476       2             Y                  ball          1            2
# 2114477       2             Y         hit_into_play          2            2
# 2114478       7             Y  hit_into_play_no_out          3            1
# 2114479       8             N         called_strike          0            0
# 2114480       8             N                  ball          0            1
# 2114481       8             N         hit_into_play          1            1
# 2114482       4             Y       swinging_strike          2            2
# 2114483       6             Y       swinging_strike          0            0
# 2114484       6             Y                  foul          0            1
# 2114485       6             Y         called_strike          0            2
# 2114486       8             Y       swinging_strike          0            0
# 2114487       8             Y             foul_bunt          0            1
# 2114488       8             Y                  foul          0            2
# 2114489       8             Y         hit_into_play          0            2
# 2114490       8             N         hit_into_play          2            1
# 2114491       4             N         called_strike          0            0
# 2114492       4             N                  ball          0            1
# 2114493       4             N         called_strike          1            1
# 2114494       4             N                  ball          1            2
# 2114495       4             N                  ball          2            2
# 2114496       4             N  hit_into_play_no_out          3            2
#
#          pre_outs  batter_id bat_side  pitcher_id throws pitch_type  \
# 0               2     407886        R      450308      R         FF
# 1               2     407886        R      450308      R         FT
# 2               2     407886        R      450308      R         FF
# 3               2     407886        R      450308      R         CH
# 4               2     407886        R      450308      R         CH
# 5               2     407886        R      450308      R         SL
# 6               2     407886        R      450308      R         FC
# 7               1     502317        R      450308      R         FC
# 8               1     502317        R      450308      R         FC
# 9               1     502317        R      450308      R         SL
# 10              2     435062        R      459967      R         SL
# 11              2     435062        R      459967      R         FT
# 12              0     450308        R      456501      R         FT
# 13              0     450308        R      456501      R         SL
# 14              0     450308        R      456501      R         FC
# 15              0     450308        R      456501      R         SL
# 16              1     430947        L      456501      R         FC
# 17              1     430947        L      456501      R         FC
# 18              1     430947        L      456501      R         FF
# 19              1     446359        R      572070      R         FC
# 20              1     446359        R      572070      R         SL
# 21              1     446359        R      572070      R         FC
# 22              1     446359        R      572070      R         SL
# 23              1     446359        R      572070      R         FF
# 24              2     435062        R      459967      R         SL
# 25              2     435062        R      459967      R         FF
# 26              0     458015        L      450275      R         FF
# 27              0     458015        L      450275      R         SL
# 28              0     458015        L      450275      R         SL
# 29              0     458015        L      450275      R         FF
# ...           ...        ...      ...         ...    ...        ...
# 2114467         1     431151        R      595014      R         SL
# 2114468         1     431151        R      595014      R         SI
# 2114469         0     543685        R      544727      R         SI
# 2114470         0     543685        R      544727      R         SI
# 2114471         0     543685        R      544727      R         SL
# 2114472         0     543685        R      544727      R         SI
# 2114473         0     543685        R      544727      R         SI
# 2114474         2     600474        R      594798      R         FF
# 2114475         2     600474        R      594798      R         FF
# 2114476         2     600474        R      594798      R         CU
# 2114477         2     600474        R      594798      R         CU
# 2114478         2     519208        L      477003      L         FF
# 2114479         0     501571        R      595014      R         SI
# 2114480         0     501571        R      595014      R         SL
# 2114481         0     501571        R      595014      R         SI
# 2114482         1     150029        R      594798      R         CH
# 2114483         1     543685        R      548337      R         FT
# 2114484         1     543685        R      548337      R         FF
# 2114485         1     543685        R      548337      R         FT
# 2114486         0     572191        R      461325      R         FF
# 2114487         0     572191        R      461325      R         CH
# 2114488         0     572191        R      461325      R         FF
# 2114489         0     572191        R      461325      R         FS
# 2114490         2     543484        R      433585      L         CH
# 2114491         1     493316        R      543699      R         SL
# 2114492         1     493316        R      543699      R         SL
# 2114493         1     493316        R      543699      R         FT
# 2114494         1     493316        R      543699      R         FT
# 2114495         1     493316        R      543699      R         FT
# 2114496         1     493316        R      543699      R         SL
#
#          Runneron1st_ID  Runneron2nd_ID  Runneron3rd_ID
# 0                   NaN             NaN        425783.0
# 1                   NaN             NaN        425783.0
# 2                   NaN             NaN        425783.0
# 3                   NaN             NaN        425783.0
# 4                   NaN             NaN        425783.0
# 5                   NaN             NaN        425783.0
# 6                   NaN             NaN        425783.0
# 7                   NaN             NaN             NaN
# 8                   NaN             NaN             NaN
# 9                   NaN             NaN             NaN
# 10                  NaN        461865.0             NaN
# 11                  NaN        461865.0             NaN
# 12                  NaN             NaN             NaN
# 13                  NaN             NaN             NaN
# 14                  NaN             NaN             NaN
# 15                  NaN             NaN             NaN
# 16             545361.0             NaN             NaN
# 17             545361.0             NaN             NaN
# 18             545361.0             NaN             NaN
# 19                  NaN             NaN             NaN
# 20                  NaN             NaN             NaN
# 21                  NaN             NaN             NaN
# 22                  NaN             NaN             NaN
# 23                  NaN             NaN             NaN
# 24                  NaN        461865.0             NaN
# 25                  NaN        461865.0             NaN
# 26                  NaN             NaN             NaN
# 27                  NaN             NaN             NaN
# 28                  NaN             NaN             NaN
# 29                  NaN             NaN             NaN
# ...                 ...             ...             ...
# 2114467             NaN             NaN             NaN
# 2114468             NaN             NaN             NaN
# 2114469             NaN             NaN             NaN
# 2114470             NaN             NaN             NaN
# 2114471             NaN             NaN             NaN
# 2114472             NaN             NaN             NaN
# 2114473             NaN             NaN             NaN
# 2114474        572191.0        435622.0             NaN
# 2114475        572191.0        435622.0             NaN
# 2114476        572191.0        435622.0             NaN
# 2114477        572191.0        435622.0             NaN
# 2114478             NaN             NaN             NaN
# 2114479             NaN             NaN             NaN
# 2114480             NaN             NaN             NaN
# 2114481             NaN             NaN             NaN
# 2114482             NaN             NaN             NaN
# 2114483             NaN             NaN             NaN
# 2114484             NaN             NaN             NaN
# 2114485             NaN             NaN             NaN
# 2114486             NaN             NaN             NaN
# 2114487             NaN             NaN             NaN
# 2114488             NaN             NaN             NaN
# 2114489             NaN             NaN             NaN
# 2114490             NaN             NaN             NaN
# 2114491             NaN             NaN             NaN
# 2114492             NaN             NaN             NaN
# 2114493             NaN             NaN             NaN
# 2114494             NaN             NaN             NaN
# 2114495             NaN             NaN             NaN
# 2114496             NaN             NaN             NaN
#
# [2114259 rows x 18 columns]

# %%
baseball_sel.pitch_type.value_counts()
# Out:
# FF    742398
# SL    312673
# FT    276923
# CH    219107
# SI    181221
# CU    172037
# FC    117789
# KC     37434
# FS     31235
# KN     10039
# IN      9774
# FO      1411
# EP      1043
# PO       873
# SC       138
# FA        84
# UN        75
# AB         5
# Name: pitch_type, dtype: int64

# %%
baseball_sel.pitcher_id.value_counts().hist(bins=200)
#plt.xlim(0,200)
pass

# %%
baseball_sel.pitcher_id.value_counts()
# Out:
# 448306    10610
# 453286    10366
# 285079    10264
# 452657    10226
# 502188    10097
# 500779    10034
# 458681     9961
# 430935     9879
# 518516     9868
# 501957     9825
# 456034     9817
# 433587     9641
# 489119     9563
# 451596     9462
# 453178     9453
# 519242     9423
# 527054     9405
# 477132     9402
# 450172     9272
# 425844     9253
# 434378     9232
# 279824     9201
# 519455     9199
# 571946     9135
# 572971     9113
# 407793     9057
# 425386     9057
# 446372     9053
# 150359     8980
# 502190     8877
#           ...
# 545338       17
# 425543       16
# 489232       16
# 543178       16
# 543094       15
# 455117       15
# 519048       15
# 453203       14
# 493337       14
# 502356       13
# 476270       13
# 150348       12
# 488748       12
# 425560       12
# 460269       12
# 434633       11
# 450317       10
# 425206        9
# 519208        9
# 459439        7
# 407489        6
# 471868        5
# 453539        5
# 489138        5
# 543281        4
# 453531        4
# 506560        2
# 456121        2
# 518614        2
# 457456        1
# Name: pitcher_id, dtype: int64

# %%
baseball_sel[baseball_sel.pitcher_id == 477132].game_id.value_counts().mean()
# Out:
# 102.19565217391305

# %%
clayton_types = baseball_sel[baseball_sel.pitcher_id == 477132].pitch_type

# %%
len(clayton_types)
# Out:
# 9402

# %%
clayton_types.value_counts()
# Out:
# FF    5351
# SL    2493
# CU    1420
# CH     133
# IN       5
# Name: pitch_type, dtype: int64

# %%
cdc, clayton_cat = np.unique(clayton_types,return_inverse=True)

# %%
cdc
# Out:
# array(['CH', 'CU', 'FF', 'IN', 'SL'], dtype=object)

# %%
clayton_cat[0:15]
# Out:
# array([2, 4, 4, 2, 2, 4, 4, 1, 2, 4, 2, 1, 2, 1, 2])

# %%
list(clayton_types)[0:15]
# Out:
# ['FF',
#  'SL',
#  'SL',
#  'FF',
#  'FF',
#  'SL',
#  'SL',
#  'CU',
#  'FF',
#  'SL',
#  'FF',
#  'CU',
#  'FF',
#  'CU',
#  'FF']

# %%
from hmmlearn import hmm

# %%
model = hmm.MultinomialHMM(n_components=3,verbose=False,algorithm='viterbi',n_iter=1000)

# %%
model.fit([clayton_cat])
# Out:
# MultinomialHMM(algorithm='viterbi', init_params='ste', n_components=3,
#         n_iter=1000, params='ste',
#         random_state=<mtrand.RandomState object at 0x10b2844e0>,
#         startprob_prior=1.0, tol=0.01, transmat_prior=1.0, verbose=False)

# %%
model.monitor_
# Out:
# ConvergenceMonitor(history=[-9597.4132934910031, -9597.4033631009042],
#           iter=445, n_iter=1000, tol=0.01, verbose=False)

# %%
model.init_params
# Out:
# 'ste'

# %%
model.transmat_
# Out:
# array([[ 0.45820796,  0.05941577,  0.48237626],
#        [ 0.36935183,  0.49966634,  0.13098183],
#        [ 0.39179294,  0.25688283,  0.35132423]])

# %%
model.startprob_
# Out:
# array([  2.74224948e-85,   9.99760158e-01,   2.39842461e-04])

# %%
model.emissionprob_
# Out:
# array([[  8.18511248e-09,   2.28131933e-01,   3.21444984e-01,
#           1.27978246e-27,   4.50423075e-01],
#        [  6.11359725e-02,   8.06767692e-02,   7.87946792e-01,
#           2.51432015e-05,   7.02153236e-02],
#        [  1.10627891e-09,   1.06907766e-01,   7.15588273e-01,
#           1.48347882e-03,   1.76020481e-01]])

# %%
model.score([clayton_cat])
# Out:
# -9597.3935982643543

# %%
exis,zeta = model.sample(102)

# %%
plt.xlim(-5,105)
plt.ylim(-0.5, 4.5)
plt.plot(exis,'--o')
plt.axhline(3)
pass

# %%
zeta
# Out:
# array([1, 2, 1, 2, 1, 2, 0, 2, 1, 1, 1, 0, 0, 0, 2, 2, 1, 1, 2, 0, 2, 2, 2,
#        1, 1, 0, 2, 1, 1, 0, 0, 2, 2, 2, 2, 1, 1, 0, 0, 0, 0, 0, 0, 2, 0, 2,
#        0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 0, 0, 0, 2, 0, 2, 2, 1, 0, 2, 0, 2, 0,
#        2, 1, 0, 2, 2, 2, 0, 0, 2, 1, 0, 2, 0, 0, 0, 2, 0, 0, 0, 0, 2, 1, 2,
#        2, 0, 0, 2, 0, 0, 0, 2, 2, 1])
